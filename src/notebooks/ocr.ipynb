# %% [markdown]
# # OCR Notebook (Deprecated)
#
# There is no standalone OCR step in the current pipeline.
# The current ingestion flow uses `extract_documents.ipynb`, and PDFs without a text layer are recorded as `missing_text_layer` in the excluded index.
