# %% [markdown]
# # Step Notebook Template
#
# Use `src/notebooks/shared_config.json` for the shared `root_id` and step filenames.
# Keep each notebook focused on one pipeline stage and call the production `src.*` runtime modules directly.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
while not (repo_root / "src").exists() and repo_root != repo_root.parent:
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.notebooks.shared_config import load_notebook_context

ctx = load_notebook_context()
STEP_KEY = "replace_me"
step_cfg = ctx.step(STEP_KEY)
paths = ctx.paths

{
    "config_path": str(ctx.config_path),
    "root_id": ctx.root_id,
    "step_key": STEP_KEY,
    "step_keys": sorted(k for k, v in ctx.config.items() if isinstance(v, dict)),
}

# %% [markdown]
# Replace `STEP_KEY`, import the matching runtime module, then build a thin execution cell that uses `ctx.paths` and `step_cfg`.
