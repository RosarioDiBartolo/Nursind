# %% [markdown]
# # Pipeline Step Template
#
# Use this template for an optional tool or a new pipeline stage. Keep configuration and orchestration visible here; keep business logic in `core.*`.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
while not (repo_root / "pipeline.json").exists() and repo_root != repo_root.parent:
    repo_root = repo_root.parent
if not (repo_root / "pipeline.json").exists():
    raise FileNotFoundError("Open this notebook from inside the Nursind repository")

src_dir = repo_root / "src"
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from IPython.display import display
from notebooks import interface as nb
from notebooks.shared_config import load_notebook_context

ctx = load_notebook_context(repo_root / "pipeline.json")
paths = ctx.paths
step_cfg = ctx.step("replace_me")
display(nb.pipeline_overview(ctx, "replace_me"))

# %% [markdown]
# ## Controls
#
# Expose only a few operator-friendly overrides. Persistent defaults belong in `pipeline.json`.

# %%
VERBOSE = True

# %% [markdown]
# ## Inputs

# %%
# display(nb.artifact_table({"input": input_path}))

# %% [markdown]
# ## Build Options

# %%
# options = StageOptions(...)

# %% [markdown]
# ## Run

# %%
# report = run_from_options(options)
# display(nb.report_summary(report))

# %% [markdown]
# ## Inspect Results

# %%
# display(nb.artifact_table({"output": output_path}))
# display(nb.preview_csv(output_path))
